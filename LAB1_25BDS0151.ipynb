# %%
import pandas as pd

df = pd.read_csv("Suicide data.csv")
df.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796     Generation X
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27820 entries, 0 to 27819
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   country             27820 non-null  object
#  1   year                27820 non-null  int64
#  2   sex                 27820 non-null  object
#  3   age                 27820 non-null  object
#  4   suicides_no         27820 non-null  int64
#  5   population          27820 non-null  int64
#  6   suicides/100k pop   27820 non-null  float64
#  7   country-year        27820 non-null  object
#  8   HDI for year        8364 non-null   float64
#  9    gdp_for_year ($)   27820 non-null  object
#  10  gdp_per_capita ($)  27820 non-null  int64
#  11  generation          27820 non-null  object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 2.5+ MB

# %%
df.isnull().sum()
# Out:
# country                   0
# year                      0
# sex                       0
# age                       0
# suicides_no               0
# population                0
# suicides/100k pop         0
# country-year              0
# HDI for year          19456
#  gdp_for_year ($)         0
# gdp_per_capita ($)        0
# generation                0
# dtype: int64

# %%
df[df["suicides_no"] > 30]
# Out:
#           country  year     sex          age  suicides_no  population  \
# 96        Albania  1997    male  25-34 years           36      236000
# 97        Albania  1997    male  15-24 years           33      244400
# 110       Albania  1998  female  15-24 years           32      295600
# 123       Albania  1999    male  35-54 years           31      391100
# 145       Albania  2001    male  35-54 years           34      378826
# ...           ...   ...     ...          ...          ...         ...
# 27812  Uzbekistan  2014    male  15-24 years          347     3126905
# 27814  Uzbekistan  2014  female  25-34 years          162     2735238
# 27815  Uzbekistan  2014  female  35-54 years          107     3620833
# 27817  Uzbekistan  2014    male   5-14 years           60     2762158
# 27818  Uzbekistan  2014  female   5-14 years           44     2631600
#
#        suicides/100k pop    country-year  HDI for year  gdp_for_year ($)   \
# ...

# %%
df.sort_values(by="population")
# Out:
#              country  year     sex          age  suicides_no  population  \
# 14167       Kiribati  2000    male    75+ years            0         278
# 14059       Kiribati  1991    male    75+ years            0         278
# 14071       Kiribati  1992    male    75+ years            0         286
# 14107       Kiribati  1995    male    75+ years            0         287
# 14083       Kiribati  1993    male    75+ years            0         290
# ...              ...   ...     ...          ...          ...         ...
# 27101  United States  2006    male  35-54 years        10641    43139910
# 27081  United States  2004  female  35-54 years         3399    43240905
# 27093  United States  2005  female  35-54 years         3209    43509335
# 27117  United States  2007  female  35-54 years         3525    43607902
# 27105  United States  2006  female  35-54 years         3376    43805214
#
#        suicides/100k pop       country-year  HDI for year   gdp_for_year ($)   \
# ...

# %%
df.shape
# Out:
# (27820, 12)

# %%
df.sort_values(by="population",ascending=True)
# Out:
#              country  year     sex          age  suicides_no  population  \
# 14167       Kiribati  2000    male    75+ years            0         278
# 14059       Kiribati  1991    male    75+ years            0         278
# 14071       Kiribati  1992    male    75+ years            0         286
# 14107       Kiribati  1995    male    75+ years            0         287
# 14083       Kiribati  1993    male    75+ years            0         290
# ...              ...   ...     ...          ...          ...         ...
# 27101  United States  2006    male  35-54 years        10641    43139910
# 27081  United States  2004  female  35-54 years         3399    43240905
# 27093  United States  2005  female  35-54 years         3209    43509335
# 27117  United States  2007  female  35-54 years         3525    43607902
# 27105  United States  2006  female  35-54 years         3376    43805214
#
#        suicides/100k pop       country-year  HDI for year   gdp_for_year ($)   \
# ...

# %%
male = df[df["sex"] == "male"]
female = df[df["sex"] == "female"]

combined = pd.concat([male, female], ignore_index=True)

combined.head()
# Out:
#    country  year   sex          age  suicides_no  population  \
# 0  Albania  1987  male  15-24 years           21      312900
# 1  Albania  1987  male  35-54 years           16      308000
# 2  Albania  1987  male    75+ years            1       21800
# 3  Albania  1987  male  25-34 years            9      274300
# 4  Albania  1987  male  55-74 years            1      137500
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.59  Albania1987           NaN      2,156,624,900
# 3               3.28  Albania1987           NaN      2,156,624,900
# 4               0.73  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)       generation
# 0                 796     Generation X
# 1                 796           Silent
# 2                 796  G.I. Generation
# ...

# %%
gdp = df[["country", "year", "gdp_per_capita ($)"]].drop_duplicates()

merged = pd.merge(
    df,
    gdp,
    on=["country", "year"],
    how="left"
)

merged.head()
# Out:
#    country  year     sex          age  suicides_no  population  \
# 0  Albania  1987    male  15-24 years           21      312900
# 1  Albania  1987    male  35-54 years           16      308000
# 2  Albania  1987  female  15-24 years           14      289700
# 3  Albania  1987    male    75+ years            1       21800
# 4  Albania  1987    male  25-34 years            9      274300
#
#    suicides/100k pop country-year  HDI for year  gdp_for_year ($)   \
# 0               6.71  Albania1987           NaN      2,156,624,900
# 1               5.19  Albania1987           NaN      2,156,624,900
# 2               4.83  Albania1987           NaN      2,156,624,900
# 3               4.59  Albania1987           NaN      2,156,624,900
# 4               3.28  Albania1987           NaN      2,156,624,900
#
#    gdp_per_capita ($)_x       generation  gdp_per_capita ($)_y
# 0                   796     Generation X                   796
# ...

# %%
gdp_df = df[["country", "year", "gdp_per_capita ($)"]].drop_duplicates()

gdp_df.head()
# Out:
#     country  year  gdp_per_capita ($)
# 0   Albania  1987                 796
# 12  Albania  1988                 769
# 24  Albania  1989                 833
# 36  Albania  1992                 251
# 48  Albania  1993                 437

# %%
continent_df = pd.DataFrame({
    "country": [
        "Albania",
        "Argentina",
        "Australia",
        "Austria",
        "Belgium",
        "Brazil"
    ],
    "continent": [
        "Europe",
        "South America",
        "Oceania",
        "Europe",
        "Europe",
        "South America"
    ],
    "income_level": [
        "Upper Middle",
        "Upper Middle",
        "High",
        "High",
        "High",
        "Upper Middle"
    ]
})

continent_df
# Out:
#      country      continent  income_level
# 0    Albania         Europe  Upper Middle
# 1  Argentina  South America  Upper Middle
# 2  Australia        Oceania          High
# 3    Austria         Europe          High
# 4    Belgium         Europe          High
# 5     Brazil  South America  Upper Middle

# %%
joined_df = pd.merge(
    gdp_df,
    continent_df,
    on="country",
    how="inner"
)
joined_df
# Out:
#      country  year  gdp_per_capita ($)      continent  income_level
# 0    Albania  1987                 796         Europe  Upper Middle
# 1    Albania  1988                 769         Europe  Upper Middle
# 2    Albania  1989                 833         Europe  Upper Middle
# 3    Albania  1992                 251         Europe  Upper Middle
# 4    Albania  1993                 437         Europe  Upper Middle
# ..       ...   ...                 ...            ...           ...
# 172   Brazil  2011               14245  South America  Upper Middle
# 173   Brazil  2012               13283  South America  Upper Middle
# 174   Brazil  2013               13191  South America  Upper Middle
# 175   Brazil  2014               12975  South America  Upper Middle
# 176   Brazil  2015                9431  South America  Upper Middle
#
# [177 rows x 5 columns]
